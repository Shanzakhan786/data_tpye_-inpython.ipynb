# %% [markdown]
# # While Loop Pratic

# %%
#Examples1: Print less than 5 numbers
#initilize the counter variable
current_number = -2
# Run the loop untill counter variable is lessthan 5
while current_number < 5:
  #print the current number
  print(current_number)

  #incerement the current number by 1 for next iteration
  current_number = current_number + 1
# Out:
# -2
# -1
# 0
# 1
# 2
# 3
# 4

# %%
#Examle2: Calaculate the Sum of first 10 natural numbers

# Set the uper limit for the  calculation sum
num = 10
#initialize the sum variable to store the cumulative sum
total_sum = 0

#initialize the counter variable foe loop
current_number = 1

#iterat through numbers from 1 to 'num'( inclusive) calculate sum
while current_number <= num :
 #add the current number to  sum
  total_sum = total_sum + current_number

  #increment the currrent number for the next iteration
  current_number = current_number + 1

  #Print the result
  print("Sum of the first 10 number is:", total_sum)
# Out:
# Sum of the first 10 number is: 1
# Sum of the first 10 number is: 3
# Sum of the first 10 number is: 6
# Sum of the first 10 number is: 10
# Sum of the first 10 number is: 15
# Sum of the first 10 number is: 21
# Sum of the first 10 number is: 28
# Sum of the first 10 number is: 36
# Sum of the first 10 number is: 45
# Sum of the first 10 number is: 55

# %%
# Initialize the sum variable to store the cumulative sum
total_sum = 0

# Initialize the counter variable for the loop
current_number = 1

# Iterate through numbers from 1 to 'num' (inclusive) and calculate the sum
while current_number <= num:
    # Add the current number to the sum
    total_sum = total_sum + current_number

    # Increment the current number for the next iteration
    current_number = current_number + 1

# Print the result
print("Sum of the first 10 numbers is:", total_sum)
# Out:
# Sum of the first 10 numbers is: 55

# %%
#Example 3: Print value of a in descending order by subtrating by 2 in each iteration
#initilize the variable a  with  the value 10
#current_value = input("Enter any number")
current_value = -1 # current_value is my variable

#Excute the loop as long as 'a' is greater than 0
while int(current_value) >= 0: #enter the body of while loop condition is true
  #Print the current value of 'a'
 print("Value of is", current_value)

  #Decrese the value of 'a' by 2 for next iteration
current_value = current_value - 2

#Print a message indicating the completion of the loop
print("Loop is Completed")
# Out:
# Loop is Completed

# %%
# Example 3: Print values of 'a' in descending order by subtracting 2 in each iteration

# Initialize the variable 'a' with the value 10
# current_value = input("Enter any number:")
current_value = 10  # 'current_value' is my variable

# Execute the loop as long as 'a' is greater than 0
while current_value > 0:  # Enter the body of the while loop because the condition is TRUE
    # Print the current value of 'a'
    print("Value of a is", current_value)

    # Decrease the value of 'a' by 2 for the next iteration
    current_value = current_value - 2

# Print a message indicating the completion of the loop
print("Loop is Completed")
# Out:
# Value of a is 10
# Value of a is 8
# Value of a is 6
# Value of a is 4
# Value of a is 2
# Loop is Completed

# %%
 #Example 4: Calculate how many times a given number can be divided by 3 before it is less than or equal to 10
 #initializ the counter variable for iterations
 iteration_count = 0

 #initalize the value of the number to be  divided
 given_number = 180

 #countines the loop while the number is greater than 10
 while given_number > 10:
  #Divide by number by 3
  given_number= given_number/3

  #Increase the count iteration
  iteration_count = iteration_count + 1

  #Print the total number of iteration is required
  print('Total iterations required:', iteration_count)
# Out:
# Total iterations required: 1
# Total iterations required: 2
# Total iterations required: 3

# %%
# Example 5: Program to add natural numbers up to sum = 1+2+3+...+n
#Take input feom user
#n = int(input("Enter n:"))

n= 10

#initialize the sum and counter
sum = 0
i=1

while i <= n:
  sum = sum + i
  i = i +1      # update counter, i.e., the value of i will change from 1 to 2 in next iteration...

  #print sum
print("the Sum is",sum)

# %%
# Take input from user
n = int(input("Enter n:"))

# Initialize the sum and counter
sum = 0
i = 1

while i <= n:
  sum = sum + i
  i = i + 1

# Print sum
print("The sum is", sum)
# Out:
# Enter n:2
# The sum is 3

# %% [markdown]
# while loop practic:

# %%
# Example 1: Print even and odd numbers between 1 and the entered number.
# get input from the user for upper limit
user_number = int(input("Please enter a number: "))

# Start the loop when the enter number is greater than 0
while user_number > 0:
  # check if the current number is even or odd
  if user_number % 2 == 0:
    print(user_number,"is an even number");
  else:
    print(user_number,"is an odd number")

  # Decrese the  number by 1 for next iteration
  user_number = user_number - 1
# Out:
# Please enter a number: 10
# 10 is an even number
# 9 is an odd number
# 8 is an even number
# 7 is an odd number
# 6 is an even number
# 5 is an odd number
# 4 is an even number
# 3 is an odd number
# 2 is an even number
# 1 is an odd number

# %%
# Get input from the user for upper limit
user_number = int(input("Please enter a number: "))

# Start the loop when the entered number is greater than 0
while user_number > 0:
  # Check if the current number is even or odd
  if user_number % 2 == 0:
    print(user_number, "is an even number")
  else:
    print(user_number, "is an odd number")

  # Decrease the number by 1 for next iteration
  user_number = user_number - 1
# Out:
# Please enter a number: 10
# 10 is an even number
# 9 is an odd number
# 8 is an even number
# 7 is an odd number
# 6 is an even number
# 5 is an odd number
# 4 is an even number
# 3 is an odd number
# 2 is an even number
# 1 is an odd number
